# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\SSOS15\\Documents\\StudentPerformance.csv")

# %%
df
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0           63             76             72               83            2020
# 1           67             71             79               85            2019
# 2           63             74             68               82            2018
# 3           75             79             88               85            2019
# 4           79             88             69               97            2020
# 5           80             83             66               86            2018
# 6           69             84             82               98            2020
# 7           75             75             82               98            2020
# 8           66             80             83               98            2018
# 9           73             85             69               96            2018
# 10          78             89             79               80            2019
# ...

# %%
df.isnull()
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0        False          False          False            False           False
# 1        False          False          False            False           False
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4        False          False          False            False           False
# 5        False          False          False            False           False
# 6        False          False          False            False           False
# 7        False          False          False            False           False
# 8        False          False          False            False           False
# 9        False          False          False            False           False
# 10       False          False          False            False           False
# ...

# %%
series = pd.isnull(df["math score"])
df[series]
# Out:
# Empty DataFrame
# Columns: [math score, reading score, writing score, placement score, club join year, placement offer count]
# Index: []

# %%
df=pd.read_csv("C:\\Users\\SSOS15\\Documents\\StudentPerformance.csv")

# %%
df
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0         66.0           76.0             82             83.0          2018.0
# 1         73.0           77.0             85             79.0          2020.0
# 2         65.0           82.0             86             85.0          2020.0
# 3         72.0           70.0             65             90.0          2020.0
# 4         72.0           76.0             73             95.0          2020.0
# 5         66.0           76.0             81             86.0          2018.0
# 6          NaN           85.0             70             93.0          2019.0
# 7         70.0           79.0             64             85.0          2018.0
# 8         69.0           89.0             67             82.0          2018.0
# 9         63.0           89.0             90             90.0          2018.0
# 10        63.0           89.0             71            100.0          2018.0
# ...

# %%
series = pd.isnull(df["math score"])
df[series]
# Out:
#    math score  reading score  writing score  placement score  club join year  \
# 6         NaN           85.0             70             93.0          2019.0
#
#    placement offer count
# 6                    3.0

# %%
df.notnull()
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0         True           True           True             True            True
# 1         True           True           True             True            True
# 2         True           True           True             True            True
# 3         True           True           True             True            True
# 4         True           True           True             True            True
# 5         True           True           True             True            True
# 6        False           True           True             True            True
# 7         True           True           True             True            True
# 8         True           True           True             True            True
# 9         True           True           True             True            True
# 10        True           True           True             True            True
# ...

# %%
series1 = pd.notnull(df["math score"])
df[series1]
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0         66.0           76.0             82             83.0          2018.0
# 1         73.0           77.0             85             79.0          2020.0
# 2         65.0           82.0             86             85.0          2020.0
# 3         72.0           70.0             65             90.0          2020.0
# 4         72.0           76.0             73             95.0          2020.0
# 5         66.0           76.0             81             86.0          2018.0
# 7         70.0           79.0             64             85.0          2018.0
# 8         69.0           89.0             67             82.0          2018.0
# 9         63.0           89.0             90             90.0          2018.0
# 10        63.0           89.0             71            100.0          2018.0
# 11        64.0           84.0             68             92.0          2018.0
# ...

# %%
m_v=df['math score'].mean()
df['math score'].fillna(value=m_v, inplace=True)
df
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0    66.000000           76.0             82             83.0          2018.0
# 1    73.000000           77.0             85             79.0          2020.0
# 2    65.000000           82.0             86             85.0          2020.0
# 3    72.000000           70.0             65             90.0          2020.0
# 4    72.000000           76.0             73             95.0          2020.0
# 5    66.000000           76.0             81             86.0          2018.0
# 6    68.607143           85.0             70             93.0          2019.0
# 7    70.000000           79.0             64             85.0          2018.0
# 8    69.000000           89.0             67             82.0          2018.0
# 9    63.000000           89.0             90             90.0          2018.0
# 10   63.000000           89.0             71            100.0          2018.0
# ...

# %%
ndf.replace(to_replace = np.nan, value = -99)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 ndf.replace(to_replace = np.nan, value = -99)
#
# NameError: name 'ndf' is not defined

# %%
ndf.replace(to_replace = np.nan, value = -99)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 ndf.replace(to_replace = np.nan, value = -99)
#
# NameError: name 'ndf' is not defined

# %%
ndf = pd.StudentPerformance({
    'col1': [1, 2, np.nan, 4],
    'col2': [5, np.nan, 7, 8]
})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 ndf = pd.StudentPerformance({
#       2     'col1': [1, 2, np.nan, 4],
#       3     'col2': [5, np.nan, 7, 8]
#       4 })
#
# AttributeError: module 'pandas' has no attribute 'StudentPerformance'

# %%
ndf.replace(to_replace=np.nan, value=-99, inplace=True)

print(ndf)
# Out:
#    col1  col2
# 0   1.0   5.0
# 1   2.0 -99.0
# 2 -99.0   7.0
# 3   4.0   8.0
